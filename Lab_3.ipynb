# %% [markdown]
# <a href="https://colab.research.google.com/github/Hyma27/FMML-lab24/blob/main/Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-16 05:40:22--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   217MB/s    in 0.3s
#
# 2025-03-16 05:40:23 (217 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 3249 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 7633   1802.05821v1  Low-rank matrix completion (MC) has achieved g...  stat
# 35150  cs/0002014v1  This paper initiates the use of vector fields ...    cs
# 6092   1607.01417v2  Cluster-wise linear regression (CLR), a cluste...  stat
# 30086  1711.06636v1  We explore encoding brain symmetry into a neur...    cs
# 33631   1411.5881v2  This paper presents a spike-based model which ...    cs
# ...             ...                                                ...   ...
# 22643  1703.05841v1  This work addresses various open questions in ...  stat
# 38973  1502.01400v3  This paper presents a new Bayesian estimation ...  stat
# 20171   1412.5077v1  The process of multiple criteria decision maki...    cs
# 12921  1711.05825v2  Approximate Bayesian computation (ABC) and syn...  stat
# 18571   1106.0239v1  We study the complexity of the combination of ...    cs
#
#                                                    title  year  \
# 7633   Learning Latent Features with Pairwise Penalti...  2018
# 35150          Safe cooperative robot dynamics on graphs  2000
# 6092   Algorithms for Generalized Cluster-wise Linear...  2016
# 30086              Segmenting Brain Tumors with Symmetry  2017
# 33631  Hardware-Amenable Structural Learning for Spik...  2014
# ...                                                  ...   ...
# 22643  Adaptivity to Noise Parameters in Nonparametri...  2017
# 38973  Fast unsupervised Bayesian image segmentation ...  2015
# 20171  A Multi-criteria neutrosophic group decision m...  2014
# 12921                  Bootstrapped synthetic likelihood  2017
# 18571  The Complexity of Reasoning with Cardinality R...  2011
#
#                                                 keywords
# 7633   [completion, applications, formulation, predic...
# 35150  [initiates, implement, schedules, cooperative,...
# 6092   [regression, clustering, intertwined, regressi...
# 30086  [segmentation, symmetric, abstraction, asymmet...
# 33631  [functionally, dendritic, compartments, classi...
# ...                                                  ...
# 22643  [addresses, questions, nonparametric, classifi...
# 38973  [estimation, technique, regularisation, parame...
# 20171  [determining, alternatives, selection, impreci...
# 12921  [approximate, computation, synthetic, likeliho...
# 18571  [complexity, combination, description, termino...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 7633     [completion, applications, formulation, predic...
# 35150    [initiates, implement, schedules, cooperative,...
# 6092     [regression, clustering, intertwined, regressi...
# 30086    [segmentation, symmetric, abstraction, asymmet...
# 33631    [functionally, dendritic, compartments, classi...
#                                ...
# 1521     [answering, challenging, information, retrieva...
# 11715    [collaborative, personalized, according, objec...
# 29428    [attractiveness, different, significant, appea...
# 2118     [interested, probability, distribution, genera...
# 7320     [detecting, distribution, distribution, distri...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8675 words.
# Out of those 4539 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6d33f614-8010-4cba-8c53-52bc3c8a0864" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d33f614-8010-4cba-8c53-52bc3c8a0864")) {                    Plotly.newPlot(                        "6d33f614-8010-4cba-8c53-52bc3c8a0864",                        [{"x":["guarantee","theoretically","important","situation","completion","dissimilar","optimization","synthetic","applications","convergence","formulation","performance","similarities","difference","subgroups","variables","statistical","particular","efficient","exploited","uniformly","extensive","estimator","influenced","complexity","penalties","algorithm","characterized","likelihood","demonstrate","prediction","factorization","characterize","approaches","developed","experiments","functions","theoretical","regularized","framework","concerning","euclidean","collisions","implement","controller","schedules","addressed","achievement","initiates","regularization","predefined","configuration","cooperative","automated","nontrivial","operating","procedure","generalize","promotions","intertwined","predictors","observation","variances","generated","generation","algorithms","performed","heuristic","mathematical","clustering","regression","promotion","programming","regressions","minimized","mechanisms","forecasting","generalized","different","supermarket","metaheuristic","abstraction","segmentation","asymmetric","asymmetries","challenge","segmenting","potential","efficiently","symmetric","information","attention","benchmark","structural","integrated","classifying","connection","biological","dimensional","evaluated","processed","connectivity","computational","classification","incorporated","dendritic","neuromorphic","utilizing","enhancing","comparable","compartments","plasticity","resources","correlated","techniques","nonlinearly","mechanism","functionally","fundamental","discovers","convolutional","collected","probabilistic","summarization","incorporates","discovery","simultaneously","understanding","dependency","application","unprecedented","visualization","outperforms","meaningful","introduce","traditional","motivating","exploratory","characterization","successful","representations","structure","nonparametric","unsupervised","algorithmic","interesting","autoencoders","engineering","directional","difficult","nonlinear","industrial","distributed","formulate","derivatives","scalability","advertising","regularizers","associated","unlabeled","naturally","affinities","implemented","stochastic","additional","available","limitations","implementation","generalization","technique","subsequently","generalizes","constrained","shortcomings","laplacian","eigenspace","constraints","dimension","improvement","orthogonal","embedding","overcomes","combination","contribution","advantage","investigate","interactions","execution","reasoning","simulated","explicitly","represents","orderings","universally","commitments","commitment","strategies","supervised","induction","inference"],"y":[28,43,346,31,34,2,291,133,418,121,76,878,34,57,1,133,148,281,376,29,17,186,23,12,219,5,817,25,75,570,220,43,42,407,178,607,201,164,36,542,12,35,6,77,22,10,35,2,1,74,16,28,11,99,5,27,118,61,0,2,13,60,7,180,160,552,141,59,69,138,133,0,120,0,13,55,12,79,737,0,8,21,194,10,2,147,20,159,152,23,699,190,201,87,54,39,44,35,183,152,25,17,264,528,18,4,16,33,16,94,2,11,74,22,351,1,128,5,79,6,373,71,148,27,39,44,100,157,47,265,15,23,262,40,330,182,2,8,33,72,227,322,15,138,50,63,16,36,17,149,59,13,104,50,11,36,3,7,113,38,64,0,103,127,116,296,42,134,119,227,24,34,58,16,14,2,141,73,136,18,111,9,145,67,86,150,74,35,123,71,66,44,4,2,1,6,96,174,20,203],"type":"bar"},{"x":["guarantee","theoretically","important","situation","completion","dissimi ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4539,), (4539, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8291666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style=''>FF</span> <span style=''>Planning</span> <span style=''>System</span> <span style=''>Fast</span> <span style=''>Plan</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>Generation</span> <span style=''>Through</span> <span style='background-color:rgba(0, 255, 0, 0.31111111111111117);'>Heuristic</span> <span style=''>Search</span> <br/><br/><span style=''>We</span> <span style=''>describe</span> <span style=''>and</span> <span style=''>evaluate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithmic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>that</span> <span style=''>are</span> <span style=''>used</span> <span style=''>in</span> <span style=''>the</span> <span style=''>FF</span> <span style=''>planning</span> <span style=''>system</span> <span style=''>Like</span> <span style=''>the</span> <span style=''>HSP</span> <span style=''>system</span> <span style=''>FF</span> <span style=''>relies</span> <span style=''>on</span> <span style=''>forward</span> <span style=''>state</span> <span style=''>space</span> <span style=''>search</span> <span style=''>using</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.31111111111111117);'>heuristic</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimates</span> <span style=''>goal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <span style=''>by</span> <span style=''>ignoring</span> <span style=''>delete</span> <span style=''>lists</span> <span style=''>Unlike</span> <span style=''>HSPs</span> <span style='background-color:rgba(0, 255, 0, 0.31111111111111117);'>heuristic</span> <span style=''>our</span> <span style=''>method</span> <span style=''>does</span> <span style=''>not</span> <span style=''>assume</span> <span style=''>facts</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independent</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>search</span> <span style=''>strategy</span> <span style=''>that</span> <span style=''>combines</span> <span style=''>hill</span> <span style=''>climbing</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>systematic</span> <span style=''>search</span> <span style=''>and</span> <span style=''>we</span> <span style=''>show</span> <span style=''>how</span> <span style=''>other</span> <span style=''>powerful</span> <span style='background-color:rgba(0, 255, 0, 0.31111111111111117);'>heuristic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.6503496503496504);'>extracted</span> <span style=''>and</span> <span style=''>used</span> <span style=''>to</span> <span style=''>prune</span> <span style=''>the</span> <span style=''>search</span> <span style=''>space</span> <span style=''>FF</span> <span style=''>was</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>successful</span> <span style='background-color:rgba(0, 255, 0, 0.5158730158730158);'>automatic</span> <span style=''>planner</span> <span style=''>at</span> <span style=''>the</span> <span style=''>recent</span> <span style=''>AIPS</span> <span style=''>2000</span> <span style=''>planning</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>competition</span> <span style=''>We</span> <span style=''>review</span> <span style=''>the</span> <span style=''>results</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>competition</span> <span style=''>give</span> <span style=''>data</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Enhancing</span> <span style=''>Pure</span> <span style=''>Pixel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Identification</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Performance</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Preconditioning</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>analyze</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>preconditionings</span> <span style=''>designed</span> <span style=''>to</span> <span style=''>enhance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>robustness</span> <span style=''>of</span> <span style=''>pure</span> <span style=''>pixel</span> <span style=''>search</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>which</span> <span style=''>are</span> <span style=''>used</span> <span style=''>for</span> <span style=''>blind</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hyperspectral</span> <span style=''>unmixing</span> <span style=''>and</span> <span style=''>which</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equivalent</span> <span style=''>to</span> <span style=''>near</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonnegative</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>Our</span> <span style=''>analysis</span> <span style=''>focuses</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>successive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projection</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>(SPA)</span> <span style=''>a</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>and</span> <span style=''>provably</span> <span style=''>robust</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>in</span> <span style=''>the</span> <span style=''>pure</span> <span style=''>pixel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>class</span> <span style=''>Recently</span> <span style=''>a</span> <span style=''>provably</span> <span style=''>robust</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>preconditioning</span> <span style=''>was</span> <span style=''>proposed</span> <span style=''>by</span> <span style=''>Gillis</span> <span style=''>and</span> <span style=''>Vavasis</span> <span style=''>(arXiv13102273)</span> <span style=''>which</span> <span style=''>requires</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resolution</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>semidefinite</span> <span style=''>program</span> <span style=''>(SDP)</span> <span style=''>to</span> <span style=''>find</span> <span style=''>a</span> <span style=''>data</span> <span style=''>points</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>enclosing</span> <span style=''>minimum</span> <span style=''>volume</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ellipsoid</span> <span style=''>Since</span> <span style=''>solving</span> <span style=''>the</span> <span style=''>SDP</span> <span style=''>in</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>precisions</span> <span style=''>can</span> <span style=''>be</span> <span style=''>time</span> <span style='background-color:rgba(255, 0 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Sparse</span> <span style=''>Learning</span> <span style=''>for</span> <span style=''>Large</span> <span style=''>scale</span> <span style=''>and</span> <span style=''>High</span> <span style='background-color:rgba(255, 0, 0, 0.33575317604355703);'>dimensional</span> <span style=''>Data</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3999999999999999);'>Randomized</span> <span style=''>Convex</span> <span style=''>concave</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style=''>Approach</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3999999999999999);'>randomized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style=''>theory</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>a</span> <span style=''>sparse</span> <span style=''>model</span> <span style=''>from</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>and</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.33575317604355703);'>dimensional</span> <span style=''>data</span> <span style=''>which</span> <span style=''>is</span> <span style=''>usually</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulated</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>problem</span> <span style=''>with</span> <span style=''>a</span> <span style=''>sparsity</span> <span style=''>inducing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularizer</span> <span style=''>Under</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumption</span> <span style=''>that</span> <span style=''>there</span> <span style=''>exists</span> <span style=''>a</span> <span style=''>(approximately)</span> <span style=''>sparse</span> <span style=''>solution</span> <span style=''>with</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>accuracy</span> <span style=''>we</span> <span style=''>argue</span> <span style=''>that</span> <span style=''>the</span> <span style=''>dual</span> <span style=''>solution</span> <span style=''>is</span> <span style=''>also</span> <span style=''>sparse</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximately</span> <span style=''>sparse</span> <span style=''>The</span> <span style=''>fact</span> <span style=''>that</span> <span style=''>both</span> <span style=''>primal</span> <span style=''>and</span> <span style=''>dual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style=''>are</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>motivates</span> <span style=''>us</span> <span style=''>to</span> <span style=''>develop</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3999999999999999);'>randomized</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>a</span> <span style=''>general</span> <span style=''>convex</span> <span style=''>concave</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Specifically</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>approach</span> <span style=''>combines</span> <span style=''>the</span> <span style=''>strength</span> <span style=''>of</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Information</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Maximisation</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Intrinsically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Motivated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Reinforcement</span> <span style=''>Learning</span> <br/><br/><span style=''>The</span> <span style=''>mutual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>is</span> <span style=''>a</span> <span style=''>core</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>quantity</span> <span style=''>that</span> <span style=''>has</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>in</span> <span style=''>all</span> <span style=''>areas</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>whether</span> <span style=''>this</span> <span style=''>is</span> <span style=''>in</span> <span style=''>training</span> <span style=''>of</span> <span style=''>density</span> <span style=''>models</span> <span style=''>over</span> <span style=''>multiple</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>modalities</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximising</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiency</span> <span style=''>of</span> <span style=''>noisy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transmission</span> <span style=''>channels</span> <span style=''>or</span> <span style=''>when</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>behaviour</span> <span style=''>policies</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploration</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>artificial</span> <span style=''>agents</span> <span style=''>Most</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>that</span> <span style=''>involve</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimisation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>mutual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>rely</span> <span style=''>on</span> <span style=''>the</span> <span style=''>Blahut</span> <span style=''>Arimoto</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>enumerative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exponential</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>that</span> <span style=''>is</span> <span style=''>not</span> <span style=''>suitable</span> <span style=''>for</span> <span style=''>modern</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>provides</span> <span style=''>a</span> <span style=''>new</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>scalable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimisation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>mutual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>by</span> <span style=''>merging</span> <span sty ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12722103766879886)
# 	information (0.2484008528784648)
# 	processing (0.09630419331911869)
# 	segmentation (0.0689410092395167)
# 	architecture (0.09132906894100924)
# 	experimental (0.14321250888415069)
# 	detection (0.1162046908315565)
# 	different (0.2619047619047619)
# 	convolutional (0.13255152807391613)
# 	recognition (0.13539445628997868)
#
# Some Statistics words are:
# 	distribution (0.1701913393756294)
# 	algorithms (0.2905337361530715)
# 	variables (0.14300100704934543)
# 	theoretical (0.15609264853977844)
# 	estimation (0.17069486404833836)
# 	statistical (0.15911379657603222)
# 	algorithm (0.3987915407854985)
# 	dimensional (0.18529707955689828)
# 	inference (0.19889224572004027)
# 	regression (0.1772406847935549)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="00763f79-25f6-486c-ae5b-dbc52dcbad68" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00763f79-25f6-486c-ae5b-dbc52dcbad68")) {                    Plotly.newPlot(                        "00763f79-25f6-486c-ae5b-dbc52dcbad68",                        [{"x":["guarantee","theoretically","important","situation","completion","dissimilar","optimization","synthetic","applications","convergence","formulation","performance","similarities","difference","subgroups","variables","statistical","particular","efficient","exploited","uniformly","extensive","estimator","influenced","complexity","penalties","algorithm","characterized","likelihood","demonstrate","prediction","factorization","characterize","approaches","developed","experiments","functions","theoretical","regularized","framework","concerning","euclidean","collisions","implement","controller","schedules","addressed","achievement","initiates","regularization","predefined","configuration","cooperative","automated","nontrivial","operating","procedure","generalize","promotions","intertwined","predictors","observation","variances","generated","generation","algorithms","performed","heuristic","mathematical","clustering","regression","promotion","programming","regressions","minimized","mechanisms","forecasting","generalized","different","supermarket","metaheuristic","abstraction","segmentation","asymmetric","asymmetries","challenge","segmenting","potential","efficiently","symmetric","information","attention","benchmark","structural","integrated","classifying","connection","biological","dimensional","evaluated","processed","connectivity","computational","classification","incorporated","dendritic","neuromorphic","utilizing","enhancing","comparable","compartments","plasticity","resources","correlated","techniques","nonlinearly","mechanism","functionally","fundamental","discovers","convolutional","collected","probabilistic","summarization","incorporates","discovery","simultaneously","understanding","dependency","application","unprecedented","visualization","outperforms","meaningful","introduce","traditional","motivating","exploratory","characterization","successful","representations","structure","nonparametric","unsupervised","algorithmic","interesting","autoencoders","engineering","directional","difficult","nonlinear","industrial","distributed","formulate","derivatives","scalability","advertising","regularizers","associated","unlabeled","naturally","affinities","implemented","stochastic","additional","available","limitations","implementation","generalization","technique","subsequently","generalizes","constrained","shortcomings","laplacian","eigenspace","constraints","dimension","improvement","orthogonal","embedding","overcomes","combination","contribution","advantage","investigate","interactions","execution","reasoning","simulated","explicitly","represents","orderings","universally","commitments","commitment","strategies","supervised","induction","inference","represented","probabilities","utterances","posterior","promising","estimated","switchboard","baselines","introduces","representing","intuition","extracted","dropconnect","corollary","inherently","dimensionality","conditional","generating","intrinsic","underlying","extraction","handwritten","recognition","chervonenkis","discriminative","sacrificing","minimization","objective","selection","achieving","collection","identifies","recursive","approximate","predictions","empirical","adaptively","polygonal","decomposition","motivated","parameters","stringent","hybridizing","advantages","preliminary","summation","estimating","parametric","transformations","presented","assumptions","accurately","appealing","combinatorial","scenarios","clutt ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	promotions
# 	promotion
# 	regressions
# 	supermarket
# 	affinities
# 	metabolites
# 	subexponential
# 	microbial
# 	spectrometry
# 	procrustes
# 	cytometry
# 	whitening
# 	revolution
# 	assimilation
# 	hydrology
# 	unnormalized
# 	epidemiology
# 	blockmodel
# 	regularised
# 	collapsed
# Some words which never appear in Statistics papers:
# 	collisions
# 	achievement
# 	compartments
# 	plasticity
# 	functionally
# 	orderings
# 	utterances
# 	switchboard
# 	dropconnect
# 	polygonal
# 	compensation
# 	disability
# 	malfunction
# 	lexicalized
# 	predicates
# 	depicting
# 	dempsters
# 	evidential
# 	navigation
# 	initiated

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.060069157562961e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7816666666666666
